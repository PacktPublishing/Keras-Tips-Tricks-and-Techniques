# %% [markdown]
# # Text Generation with Keras
# This notebook explores how to train a Keras model to generate text in the style of William Shakespeare

# %%
from __future__ import print_function
from keras.callbacks import LambdaCallback
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
import numpy as np
import random
import sys
import io

# %% [markdown]
# Let's load the text file containing all of Shakespeare's works. Check out Project Gutenburg to access the full text.

# %%
path = 'shakespeare.txt'
with io.open(path, encoding='utf-8') as f:
    text = f.read().lower()
print('corpus length:', len(text))
# Out:
# corpus length: 5573152

# %% [markdown]
# Now let's cut the text up into 40 character sequences to make it simpler to build sequences for training

# %%
chars = sorted(list(set(text)))
print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))

maxlen = 40
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences))
# Out:
# total chars: 79
# nb sequences: 1857704

# %% [markdown]
# Now lets vectorize this

# %%
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1

# %% [markdown]
# Now we can build our model - note that the layer here we are using is LSTM, a form of Recurrent Neural Network

# %%
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars), activation='softmax'))

optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %% [markdown]
# Let's define a function for sampling predictions at the end of each epoch

# %%
def sampler(prediction, temperature):
    prediction = np.asarray(prediction).astype('float64')
    prediction = np.log(prediction) / temperature
    exp_prediction = np.exp(prediction)
    final_pred = exp_prediction / np.sum(exp_prediction)
    prob = np.random.multinomial(1, final_pred, 1)
    return np.argmax(prob)

# %% [markdown]
# Let's define a function that allows us, at the end of each epoch, to output a sample of what the model has learned.

# %%
def on_epoch_end(epoch, _):
    print()
    print('Generating text after Epoch: %d' % epoch)

    start_index = random.randint(0, len(text) - maxlen - 1)
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print('----- diversity:', diversity)

        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sampler(preds, diversity)
            next_char = indices_char[next_index]

            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()

print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

model.fit(x, y,
          batch_size=10000,
          epochs=10,
          callbacks=[print_callback])
# Out:
# Epoch 1/10
# 1857704/1857704 [==============================] - 1166s 628us/step - loss: 2.5464
#
# Generating text after Epoch: 0
# ----- diversity: 0.2
# ----- Generating with seed: "
# it blesseth him that gives and him that"
#
# it blesseth him that gives and him that the wird he wer the do the come the come the come the dome ser and the for her the so her be the prowe the have the will be the the wis and so ser so dest of the word of her the bear and the deen so me the sore the so and a do she so mand her a dous and the so dest in the will the be the will the will i
# ----- diversity: 0.5
# ----- Generating with seed: "
# it blesseth him that gives and him that"
#
# it blesseth him that gives and him that the me the bear, and me the come, and bet gone of lase of why my the mare?
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "
# it blesseth him that gives and him that"
#
# it blesseth him that gives and him that elale with encey, sor com
#     o’g
#     now whows rid wo maent pors ofer now, deyorose, whfy can lenk: nome
# and, the soop
#     lake; but my fole lord,
# i my all in?
#
#  ladeat ontes
# bying the erigh,
#   wemld pane be rufl
# ade you wigh a dournie nooreded our mury. why the mofren! we dead sers     earsee.
#   eni; thtt beee tont nou be wes the br cone—
#
#         w6teo k and for wigh,
# whou pave nich he for fou
# ----- diversity: 1.2
# ----- Generating with seed: "
# it blesseth him that gives and him that"
#
# it blesseth him that gives and him that hor shle ast 9dere hendshianteffze,
# an, the so
# wast vo chdor her, closbe foa dire ow seaf rave muse wingebriin.
#
# fince;
# 1i hathsnale, on gomoner calk; you wirad undeved, anthrs, in? he
# add; sur’s lentrte@m   ferver’s;
#   d ' spounrer cand, . drorcose’s des seve; sy; wegt”
#
# ib by bensh you.
#
# i[ho. tim; hir pathy and sald thing thassr.
# i fauns
# por-pome sarsars mo nod
#   ontu(to ar the thao dwe xelfe
# Epoch 2/10
# 1857704/1857704 [==============================] - 998s 537us/step - loss: 1.8593
#
# Generating text after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: "n; in the which better part i have saved"
# n; in the which better part i have saved,
#     and the for the for the come the consenter the for the tone to the worded
#     and the lord of the lord and the for the come of the manter the consenter the tould hearted a forth the thee
#     and seeper the come the perace of the sealted and seepers the for the worth of the tould the thee and the consenter and the senter the bearted the manter her heart
#     the laid the for the come of the mo
# ----- diversity: 0.5
# ----- Generating with seed: "n; in the which better part i have saved"
# n; in the which better part i have saved and the the did
#     and reading her canst be the gains and thoughter and thought,
# and what averane and for of the world.
#
# blook.
# why the for heart of have sheer and heart
#
#                                           exit
#
#                                                                                                        exeunt
#     a forther to to your hand in offeres the restand as gover to the
# ----- diversity: 1.0
# ----- Generating with seed: "n; in the which better part i have saved"
# n; in the which better part i have saved wellowe
#     not worl:
# marrough.
#
# aiglushing gion would
#    tiee he reading you dolare, and floud, and your
# speikes till-love up her?
#  larvily.
# prabge.
#
# faltiolo.
# gry emeiless and wheatal for hithor ely.
# wither chomit, madie!
#
# brosebsat gands,
# that all sourtedief strave, that the enaly houre
# be agy balidy.
#   carolumi. by it; fentuted prandees in ar-ere to me!
#
#
#       tinsengpubagox.
# i would then ma
# ----- diversity: 1.2
# ----- Generating with seed: "n; in the which better part i have saved"
# n; in the which better part i have saved
# herken!
#   duke. your popy, reforghy digtorshrems hoeds's? lettay,
#   to thon ford doundy doy a blave your prockes
#
#
# al sulried._o.
#   orvilrio. hakery and me!
# if aras; she-takesil.—ricpake!
#   jory aberacuer had gavibee” do chould endedbear
# of alsife, loven fone,
# wishe;ficly;
#   robuthyeior, whilns’ll lost so go?
#
# eychounslawus ot not menching erosga’s wis man hangarfauty frrenisbegved-(thy.—
#
# eloste
# Epoch 3/10
# 1857704/1857704 [==============================] - 990s 533us/step - loss: 1.6782
#
# Generating text after Epoch: 2
# ----- diversity: 0.2
# ----- Generating with seed: "s.
# i know not what the success will be, "
# s.
# i know not what the success will be, to the court of the soul.
#     that well the court of the court of the hand.
#
#  [_exeunt._]
#
#
#
#
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "s.
# i know not what the success will be, "
# s.
# i know not what the success will be, what i have beard.
#
#  [_exeunt._]
#
# scene ii. john.
#                                                                  exeunt lady to me and here,
# and there is me do stand him not thank in the moon hand of the tame in the with of that is the dead of the done.
#     who hourt of me do not a hand of sime
# of man, he court of the good would enter;
# love and trote to at the come to be the fare, but and nother
# ----- diversity: 1.0
# ----- Generating with seed: "s.
# i know not what the success will be, "
# s.
# i know not what the success will be, wars.
#   flawio. god offer dusitor lite thane in acrome
# of tranke up, fall true alve, was my pettalsill,
#   all plear, alu coudious gravish, for make bouth,
# a day it prias, hame senct, gever walks. in.
#   scriving. would ressice,
# thoughts you, gaulthia. yot.
#   woll ark jessading. atterpak, yet or brood to cour of
#     jouts putry
#     well are beace,
# muching, boob, yet? apter for his dood.
#     is nield
# ----- diversity: 1.2
# ----- Generating with seed: "s.
# i know not what the success will be, "
# s.
# i know not what the success will be, gentlences,
# neever.
#
# o, my lorted flotere
# “costiken affeccecitied- ’ll fonce polone!
#    doremas in lith cousit. will thon, masaffeabe!
# teeposbhizalus, to lidd juint to thing
# like quiet mreclian, it is tows chiake in.
# the your frie-d-y todateron butid,
#     and 'teet id. go wak? eyen anpech-town theice;
# [_myscorgelic] aboluce,
# o ifancom’d. too. we.
# imp that; wifthousia glamidy? amoten everce i covel
# Epoch 4/10
# 1857704/1857704 [==============================] - 991s 534us/step - loss: 1.5871
#
# Generating text after Epoch: 3
# ----- diversity: 0.2
# ----- Generating with seed: "at here all day.
#
#                       "
# at here all day.
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "at here all day.
#
#                       "
# at here all day.
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "at here all day.
#
#                       "
# at here all day.
#
#                              'tith the king our the atrest,
# by st a fasliow, if these deneed rite;
# i maid, sir?
#
# pampoter.
# their many with paeding away this bearing
# is came neer comes glors and contrement
#     do plain their same most i dear's our hiant,
#     thou assiper tell the fave hopht aching'isl’d there, if abouts with the in young,
# i            exeunt pare] mo, you are the all foul in a mer yrecheile.
#   vold. but
# ----- diversity: 1.2
# ----- Generating with seed: "at here all day.
#
#                       "
# at here all day.
#
#                         exeunt
#
# lock, is trult beliad thus cautce?
#
# quick iltolia.
# ays, i have no my thyseciain you he.
# ovatomes the heems; nupomens, that you she day.
#
# pesscomore.
# farechournes of yor he waltiet gliee]         exeemon o’el,
#
# herrew.
# lett shapgry:
# so
#     the quay ord a driev’s,
# day-have sun, crie ment
#   but it is yet thou sep enfliudd as i all luct
#     so the shumbites is dechear'st, i coprien;
# with gri
# Epoch 5/10
# 1857704/1857704 [==============================] - 987s 531us/step - loss: 1.5334
#
# Generating text after Epoch: 4
# ----- diversity: 0.2
# ----- Generating with seed: "e sense in that than in reputation. repu"
# e sense in that than in reputation. repure the diest the counter the field the death,
#     the princes the proved the death of the counter.
#
#  [_exit._]
#
# scene ii. a rodering.
# ay, there is she she should the courtess
#     the prince the show the proper the courtest.
#     the prince the sense the present the princes,
#     the should the stand the true the mother.
#
#  [_exeunt counter of the speck’d of the princes,
#     the state the stand the pr
# ----- diversity: 0.5
# ----- Generating with seed: "e sense in that than in reputation. repu"
# e sense in that than in reputation. repure
# that i should die the main but let me to see then the cardining die
#     that i have this fore the the with the while.
#
#  [_exit._]
#
# haplia.
# not deep the dead, the lady the singlence;
#     i should have stall when you must the more the devilent then trease
#     the trull my heart them the child them him delight.
#   chesse. now she were the strange the with the stand they for the fear.
#
#  enter latenc
# ----- diversity: 1.0
# ----- Generating with seed: "e sense in that than in reputation. repu"
# e sense in that than in reputation. repurience should intercames;
# the maevely for my perenitest considediag?
#   is. toway. i will negern my kneeved unfine nature:
# and you mayse him, he? where is thou shile not.
#
#  enter preyio.
#
# amity.
# they ’ay needs.
#
# hereacks.
# tonk, here, i tirned truel with depines a fallow;
#     to my caesar. here they most mere his hidely
#     which i night us. wearen you that it be for thee image.
#
#
# orry.
# throw the sp
# ----- diversity: 1.2
# ----- Generating with seed: "e sense in that than in reputation. repu"
# e sense in that than in reputation. repust’d, there
# in toose sickly, i bear! yet paie, i with.
#
#
# enter, but
# aip!
# thrish bat your aloar of his juitederch show you haat kison. o, these.”,
# cherick’d fextine tuckle; she
# for she help, tam, fiese drain, i your fear place,
# where is villar's logher.
#
# by.
# glouign, not thou her up all
# ’dis 10 tells you were vain;
# she receal this?
#
# partaius. tellet commandeds.
#
# beds.
# o itello, if then to hin thrin
# Epoch 6/10
# 1857704/1857704 [==============================] - 989s 532us/step - loss: 1.4972
#
# Generating text after Epoch: 5
# ----- diversity: 0.2
# ----- Generating with seed: "ss'd from him.
#   somerset. my lord,
#     "
# ss'd from him.
#   somerset. my lord,
#     and the fair say and the come the countess
#     and the bound the such a second the fool,
#     and the heart the beauty and the seese.
#     the fair cannot be so dear the stall the good and heart and see the seese
# the death the father and the brother that the heart
#     and the heart and heart and beauty and heart of the such a such a the the death
#     and so the hand and the father the beat the heart
# ----- diversity: 0.5
# ----- Generating with seed: "ss'd from him.
#   somerset. my lord,
#     "
# ss'd from him.
#   somerset. my lord,
#     were i must should he had the father she is been the beat the duke and the stall and and weep,
#     who his the would the breather of the thieves.
#     what should have your house and such a sould
#     but her purson; and i love your fail in but this sail,
#     and the counted court the cassion the tears and heaven.
#     the father the present the court a came our charge,
#     which i should be her endu
# ----- diversity: 1.0
# ----- Generating with seed: "ss'd from him.
#   somerset. my lord,
#     "
# ss'd from him.
#   somerset. my lord,
#     and though in his a geath feel-pursuff.
#
#  jucit. cates not the queeple that churces, if he
# want hitpor best please this gentleman,
#     bittey thee? i wame will be our such twe with endure
# as but loid she is a such agnyorgething
#       with ever thou, the either shall spition
# when the year the gods;
#     that he heaveng new belave the arranding,
# and whense bid you train’d half laws’s deed sleep what
#
# ----- diversity: 1.2
# ----- Generating with seed: "ss'd from him.
#   somerset. my lord,
#     "
# ss'd from him.
#   somerset. my lord,
#     lord should not of the ceasurafrors my sleep?
#
# dromio of cleakes.
# i’ll mestys, from man.’ see she feeding usurstand my savig not! near
# queater
# took us accausation. getsil him!
#
# 2.
#
# prosp.
# was
# he will nev's of th’ woeth to mer
# breokaff uptis ale is
# convence to it upons, anther?
#
# unchows.
# the chame, i’ll seve o’ll weals in litter
#     that emmanst that you here his blown with thee way bysurve.
#   cax.
# Epoch 7/10
# 1857704/1857704 [==============================] - 976s 526us/step - loss: 1.4715
#
# Generating text after Epoch: 6
# ----- diversity: 0.2
# ----- Generating with seed: "y, with honourable parts,
# proportion’d a"
# y, with honourable parts,
# proportion’d and marchion and the ford in the counters.
#     the country to me to me a prove a man.
#     what is the counterance of my heaven,
#     why shall i have i do will be a sead,
#     and the come to heaven to me to the countess,
#     which i have the come to see the country.
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "y, with honourable parts,
# proportion’d a"
# y, with honourable parts,
# proportion’d and leave to come and marching upon thee, and for his soul,
#                                                                                                                                                       exit
#
# scene ii. anowneners. i cannot come, sir, you well made with you,
#     that may be our same the please a tongue.
#
#               enter the follow and some promised sile of heaven,
#     whi
# ----- diversity: 1.0
# ----- Generating with seed: "y, with honourable parts,
# proportion’d a"
# y, with honourable parts,
# proportion’d after crown, i offeffered,
#     i wouldst my distaig't one so.
#
# bassanion.
# you dah, it is how.
# behall is from flesh shall be there indieces.
#   come.
# marry, diedly not spirit! what kive; he cale.
#
# scene-biigin.
# but alrowbowam._]
#
# berard, no; i, bith you must ows de the time.
#
#
#       heroks.
#
#
#
#       don jear.
#       no machs, greed nor look, i killing to dause, i tur,
#     what you will not were, or ad
# ----- diversity: 1.2
# ----- Generating with seed: "y, with honourable parts,
# proportion’d a"
# y, with honourable parts,
# proportion’d away; we wakes lark ere—ford; he he enter faunts day in highner; you talks?
# as it againstiech, sir.
#
# pandaro.
# i shade heavy,
#     may, yes you muse be wilt a service, i s'ad
#     with he feets! our king thepeth achee,
#     wither hedly mould me.
#
#                 one, did fave more, lasting so.
#   duchishall. i will. such beat our more lininio, right goy earso,
# our-brows of offened hus more: fare, ander
# Epoch 8/10
# 1857704/1857704 [==============================] - 985s 530us/step - loss: 1.4522
#
# Generating text after Epoch: 7
# ----- diversity: 0.2
# ----- Generating with seed: "n in the blazon of sweet beauty’s best,
# "
# n in the blazon of sweet beauty’s best,
#     and the man in the hands that i have be some some of the state.
#     therefore the fortune to make the counter to the great of the death.
#     therefore the great the prove the death.
#     therefore the prove and the counter to be a man.
#     therefore the properation of the parts
#     the proceated the free to the perfecting bear.
#
#  [_exit._]
#
# scene iii. the lady. if i will not the bear the parts,
# ----- diversity: 0.5
# ----- Generating with seed: "n in the blazon of sweet beauty’s best,
# "
# n in the blazon of sweet beauty’s best,
# come of the dead man, and in the forest stand too,
#     i shall say that the tame is contraring to dear mind,
#     but that i have with the bardon to such a taunting of our frame.
#   costard. hears the fair friend to the favour to castle.
#
# berter.
# i know not thee may not but the man in the king of boy.
#
# king.
# poor gods, macketer cares nature, the fire
#     the chance and make the took of the books,
#
# ----- diversity: 1.0
# ----- Generating with seed: "n in the blazon of sweet beauty’s best,
# "
# n in the blazon of sweet beauty’s best,
# or courtey which and pleamy.
#
# ricades.
# wes you gentlemen,
#     how, my fearle attenmer, for and present,
# what foech toby unnease the mont tairio:
# do suboner for thine!-glessing again, for that her wight,
#     in the vapterion being me thousand founds in spreested,
#     kneel you praised hath such a mernertile.
#
# aphires.
# o; you you perfessisby wither.
#
# hotse.
# suffert]
#
# falstaff.
# and can or the digncri
# ----- diversity: 1.2
# ----- Generating with seed: "n in the blazon of sweet beauty’s best,
# "
# n in the blazon of sweet beauty’s best,
# withness ramp.
# laying, power wemso much from choried will kitt’st zon.
# hath not with handment inmet i livy
# togain. sore. [exit:_]
# but god. sir; i’ll laving them with me great obse speak,
#     looks indernard, fiveiant!
#   morea. i if
#     that were i lad’s strifentience, whom i
# dong’d may.
#
# lucius.
# do wish tim, agamentass, havinius know’d
# shall murds camd cipher’s saver here,
#     iar this prince; i p
# Epoch 9/10
# 1857704/1857704 [==============================] - 986s 531us/step - loss: 1.4366
#
# Generating text after Epoch: 8
# ----- diversity: 0.2
# ----- Generating with seed: "o sudden seem,
#       i would have salv’d"
# o sudden seem,
#       i would have salv’d of the state,
# and the gods the proceated that i have stand
#     that i have the state that i have the great beard,
#     and the state him to the country.
#     what is the duke of the state and stand to me.
#     i will not be some to the companions
#     that i am some office of the state,
#     and the great and for the court of the world.
#
#  [_exit._]
#
# scene ii. a room, it is a man, and the common mind,
#
# ----- diversity: 0.5
# ----- Generating with seed: "o sudden seem,
#       i would have salv’d"
# o sudden seem,
#       i would have salv’d the lady prothers in them.
#
#  [_exit._]
#
# scene iv. a room in
#
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "o sudden seem,
#       i would have salv’d"
# o sudden seem,
#       i would have salv’d. the bowd is beg;
#     hagle is dishones more dianly?
#   duke.
#   his repure.
#   toucher. you?
#   arcucbord. upon that gears this?
#   proteus. ay, speed,
#   but have do not spoken be thou come to plubsence
# that cromes of the latter-other:  [_ex._]
#
# samb.
# how, ily truth, sir, or call.
#
# clion.
# pray you: bigervoocke aspeated hearts voice.
#
# perjury.
# as you chiding’s made who, mine eyrst infend
#   armiles, an
# ----- diversity: 1.2
# ----- Generating with seed: "o sudden seem,
#       i would have salv’d"
# o sudden seem,
#       i would have salv’d show titeby!
#
# katha.
# nothing’s proclaid honour.
# lepige!tys, and content you.
# how it in spallet.
#   king me ford, next.
#
# thersutio.
# proud thy hongures._
# ’tis thing in a will: if thou, lay young armip-
# strayle-tone of reguriale.
#
# rialig.
# helves page, toeph hamlets and ta-christisff;
#       but 'le a man with myshrator,
#     and that rove?
#   dvourg. and.
#
#
#    beholdoma! what diequy unstumperes, and dri
# Epoch 10/10
# 1857704/1857704 [==============================] - 984s 530us/step - loss: 1.4237
#
# Generating text after Epoch: 9
# ----- diversity: 0.2
# ----- Generating with seed: "rsue me lasting strife,
# if, once a widow"
# rsue me lasting strife,
# if, once a widow to the world to the serves.
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "rsue me lasting strife,
# if, once a widow"
# rsue me lasting strife,
# if, once a widow and more and achilance
#     to my man to despised the worsd upon the fortunes
#     and lady sir roberous of the duke of gloucester
#     that had the left at her watch to seems are in sour as son,
#     the duke of this shame to words, and made as forth,
#     what any that displeased me to stand,
#     and with the court of death.
#   boy. why, what with his service, and therefore not so host,
#     and i hav
# ----- diversity: 1.0
# ----- Generating with seed: "rsue me lasting strife,
# if, once a widow"
# rsue me lasting strife,
# if, once a widow of fire, comes so, peace,
# share woathow is tagsing suffer’d; i’ll be besomes
#
# woman my countessiand follows hath soracaty.
# your prustice for his vossun’st.
#
# lear.
# that in chaffourd you sitling?
#   gloucester. indeed no marthes. o, master knowly, fear him saith, by that sightly sccorms and berownes
# him in lawance, and harth, know my grade,
#     do’t hidward; i am a boast upon,
# which the ship, and to
# ----- diversity: 1.2
# ----- Generating with seed: "rsue me lasting strife,
# if, once a widow"
# rsue me lasting strife,
# if, once a widowiaved; dry bling firsh;
# now despalece's friends, kingdables and dows
# this know, burst might day the new baulm.
#
#
# these to have bound.
#
#     [to the k’er so raigon, fight. fly. ’twiltry,
# in much us
#     to his bassal to me.
#   glouceraba.swercidgy's art poning—time lord
#     hold'st, villad your honss pressademen-plix
# to that,.
#
# [_exit secrio._]
#
#  [_aster,.]
#
#
#   suipm. if your hair sham

# %% [markdown]
# Let's save the model

# %%
model.save('shakespeare_generator.h5')
